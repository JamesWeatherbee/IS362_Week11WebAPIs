# %% [markdown]
# IS 362 Week 11 Assignment: Web APIs

# %%
import json
import requests
import csv
import pandas as pd

# %%
response = requests.get("https://api.nytimes.com/svc/books/v3/lists/current/hardcover-fiction.json?api-key=WDGLPDTIMyN5xbDywt6kM7Tw5Bchr8il")
todos = json.loads(response.text)

# %%
todos_formatted = json.dumps(todos, indent=2)
# print(todos_formatted)

# %%
df = pd.read_json("https://api.nytimes.com/svc/books/v3/lists/current/hardcover-fiction.json?api-key=WDGLPDTIMyN5xbDywt6kM7Tw5Bchr8il")
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df)
df.to_string()
# Out:
#                            status  \
# bestsellers_date               OK
# books                          OK
# corrections                    OK
# display_name                   OK
# list_name                      OK
# list_name_encoded              OK
# next_published_date            OK
# normal_list_ends_at            OK
# previous_published_date        OK
# published_date                 OK
# published_date_description     OK
# updated                        OK
#
#                                                                     copyright  \
# bestsellers_date            Copyright (c) 2021 The New York Times Company....
# books                       Copyright (c) 2021 The New York Times Company....
# corrections                 Copyright (c) 2021 The New York Times Company....
# display_name                Copyright (c) 2021 The New York Times Company....
# list_name                   Copyright (c) 2021 The New York Times Company....
# ...
